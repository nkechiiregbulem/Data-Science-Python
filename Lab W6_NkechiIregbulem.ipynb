# %% [markdown]
# <p class="pull-left">
# COMP 061 - Programming for Data Science
# </p>
# <div class="pull-right">
# <ul class="list-inline">
# Copyright © Dana Nehoran 2017
# </ul>
# </div>

# %% [markdown]
#  <div style="background-color: #FFF8C6; border:1px solid #000; margin-left: 2px; margin-right: 2px;
#
# padding-bottom: 2px; padding-left: 2px; padding-right: 1px; padding-top: 10px;">
# <center><b><font size="6">Lab Week 6</font></b></center>
# </div>

# %%
# Preparation for pandas and NumPy
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import random

import matplotlib.pyplot as plt
from urllib.request import urlopen

pd.options.display.float_format = '{:,.2f}'.format

# Preparation for matplotlib
# %matplotlib inline

# %%
# The following commands allows automatic reload of the file on each run
# %load_ext autoreload
# %autoreload 2

# %%
# %%javascript
# require(
#         ["notebook/js/outputarea"],
#         function (oa) {
#             oa.OutputArea.auto_scroll_threshold = -1;
#             console.log("Setting auto_scroll_threshold to -1");
#         });

# %% [markdown]
# <blockquote style="border: 2px solid #666; padding: 10px; background-color: #99e6ff"><b> Question 1:</b> Stock Exchange Data Retrieval
# <div class="pull-right">
# Practice for homework question 1
# </div>
# </blockquote>

# %% [markdown]
# <b><font color="blue", size = 4>a)</font></b> What were the 15 most recent technology IPOs on `NYSE`?

# %% [markdown]
# <span style="background-color: #FFFF00">Your answer here</span>

# %%
exchange_columns = ['Symbol', 'Name', 'LastSale', 'MarketCap', 'IPOyear', 'Sector', 'Industry']

# %%
url = "https://www.nasdaq.com/screening/companies-by-industry.aspx?exchange=NYSE&render=download"
try:
    NYSE = pd.read_csv(urlopen(url))
    NYSE = NYSE[exchange_columns]
    NYSE = NYSE.replace('n/a',np.NaN).dropna()
    display(NYSE.head(10))
except:
    print ("Error with the following url")
    print (url)
# Out:
#    Symbol                       Name  LastSale          MarketCap  IPOyear  \
# 2    WBAI            500.com Limited     10.93     461,849,696.69 2,013.00
# 3    WUBA                58.com Inc.     70.53  10,402,433,024.40 2,013.00
# 6    ATEN         A10 Networks, Inc.      6.16     447,876,980.32 2,014.00
# 7     AAC         AAC Holdings, Inc.      7.32     180,047,661.00 2,014.00
# 12   ABBV                AbbVie Inc.     96.01 145,385,321,734.98 2,012.00
# 21    ACN              Accenture plc    174.14 111,432,186,000.00 2,001.00
# 23    ATV  Acorn International, Inc.     20.80      55,746,912.00 2,007.00
# 26   GOLF    Acushnet Holdings Corp.     26.43   1,975,886,316.75 2,016.00
# 29   AGRO             Adecoagro S.A.      7.38     860,177,612.16 2,011.00
# 30   ADNT                 Adient plc     36.88   3,443,551,910.24 2,016.00
#
#                    Sector                                         Industry
# ...

# %%
tech_df = NYSE[NYSE.Sector == "Technology"].sort_values("IPOyear", ascending = False)[0:10]
tech_df
# Out:
#      Symbol                              Name  LastSale        MarketCap  \
# 3158    ZUO                       Zuora, Inc.     21.10 2,272,868,346.90
# 278    AVLR                     Avalara, Inc.     35.75 2,376,382,973.25
# 2175   PAGS            PagSeguro Digital Ltd.     29.66 9,346,886,837.88
# 2219   PRSP                    Perspecta Inc.     26.14 4,332,196,158.76
# 2266   PVTL            Pivotal Software, Inc.     19.35 4,980,408,186.60
# 1473   HUYA                         HUYA Inc.     21.71 4,424,434,129.18
# 1461    HMI                 Huami Corporation     10.68   634,756,358.88
# 2572   SMAR                   Smartsheet Inc.     28.26 2,903,882,977.44
# 1268   GTES  Gates Industrial Corporation plc     19.18 5,557,527,349.22
# 1036   DAVA                        Endava plc     28.19 1,494,186,847.55
#
#       IPOyear      Sector                                         Industry
# 3158 2,018.00  Technology          Computer Software: Prepackaged Software
# ...

# %% [markdown]
# <b><font color="blue", size = 4>b)</font></b> What are the 10 health care companies with the largest market cap on `NYSE`?

# %% [markdown]
# <span style="background-color: #FFFF00">Your answer here</span>

# %%
tech_df = NYSE[NYSE.Sector == "Health Care"].sort_values("MarketCap", ascending = False)[0:10]
tech_df
# Out:
#      Symbol                                            Name  LastSale  \
# 12     ABBV                                     AbbVie Inc.     96.01
# 77      AGN                                   Allergan plc.    193.46
# 1400    HCA                            HCA Healthcare, Inc.    138.65
# 3156    ZTS                                     Zoetis Inc.     93.53
# 1546    IQV                            IQVIA Holdings, Inc.    130.35
# 3054    WCG                     WellCare Health Plans, Inc.    315.30
# 1883    MOH                           Molina Healthcare Inc    144.66
# 1412    HLF                        Herbalife Nutrition Ltd.     54.30
# 592    CTLT                                  Catalent, Inc.     46.34
# 630     CRL  Charles River Laboratories International, Inc.    134.37
#
#               MarketCap  IPOyear       Sector  \
# 12   145,385,321,734.98 2,012.00  Health Care
# 77    65,668,917,880.12 2,013.00  Health Care
# 1400  47,979,277,900.00 2,011.00  Health Care
# ...

# %% [markdown]
# <b><font color="blue", size = 4>c)</font></b> Select a segmentation of your own that gives you between 10 to 30 rows

# %% [markdown]
# <span style="background-color: #FFFF00">Your answer here</span>

# %%
tech_df = NYSE[NYSE.Industry == "Computer Software: Prepackaged Software"].sort_values("MarketCap", ascending = False)[0:20]
tech_df
# Out:
#      Symbol                       Name  LastSale          MarketCap  IPOyear  \
# 2157   ORCL         Oracle Corporation     49.75 188,484,748,261.00 1,986.00
# 2478    CRM         Salesforce.com Inc    159.10 120,390,970,000.00 2,004.00
# 2999    VMW               Vmware, Inc.    154.58  63,182,092,445.20 2,007.00
# 2624     SQ               Square, Inc.     96.96  39,795,107,994.24 2,015.00
# 2546    NOW           ServiceNow, Inc.    196.20  34,903,980,000.00 2,012.00
# 2970   VEEV         Veeva Systems Inc.    104.40  15,086,780,002.80 2,013.00
# 2553   SHOP               Shopify Inc.    160.20  15,077,942,298.00 2,015.00
# 2703   DATA     Tableau Software, Inc.    107.53   8,918,918,856.20 2,013.00
# 2193   PAYC      Paycom Software, Inc.    147.60   8,653,073,320.80 2,014.00
# 1864   MFGP       Micro Focus Intl PLC     18.81   8,094,438,361.35 2,017.00
# 1376   GWRE   Guidewire Software, Inc.     99.34   8,007,630,409.46 2,012.00
# ...

# %% [markdown]
# <b><font color="blue", size = 4>c)</font></b> Create a loop with the following menu items: <br>
# 1 - Search for a symbol <br>
# 2 - Search for part of the name of a company <br>
# 3 - Search for a sector <br>
# 4 - Search for an industry <br>
# 5 - Historical value <br>
# 0 - exit <br>

# %% [markdown]
# After the user selects any nubmer between 1 to 5, he/she will be asked to select between 3 options of exchange (NASDAQ, NYSE, AMEX).
#
# After the selection of the exchange, the user will be asked the next relevant question. For example if the selection was 1, the program should ask for the symbol to search

# %% [markdown]
# <span style="background-color: #FFFF00">Your answer here</span>

# %%
print ("\n\n Welcome to our Data Store")
print ("1) Search for a symbol")
print ("2) Search for part of the name of a company")
print ("3) Search for a sector")
print ("4) Search for an industry")
print ("5) Historical value")
print ("\n0) Exit")
option = input ("What is your selection? ")

your_choice = input("Please select a database from AMEX, NASDAQ, AND NYSE: ")
if (option == "1"):
    symbol = input("Please enter the symbol: ")
    if your_choice == "AMEX":
        print (AMEX[AMEX.Symbol == symbol])
    if your_choice == "NYSE":
        print (NYSE[NYSE.Symbol == symbol])
    if your_choice == "NASDAQ":
        print (NASDAQ[NASDAQ.Symbol == symbol])
if (option == "2"):
    name = input("Please enter part of the name of the company: ")
    if your_choice == "AMEX":
        print (AMEX[AMEX.Name.str.contains(name)])
    if your_choice == "NYSE":
        print (NYSE[NYSE.Name.str.contains(name)])
    if your_choice == "NASDAQ":
        print (NASDAQ[NASDAQ.str.contains(name)])
if (option == "3"):
    sector = input ("Please enter the sector: ")
    if your_choice == "AMEX":
        print (AMEX[AMEX.Sector == sector])
    if your_choice == "NYSE":
        print (NYSE[NYSE.Sector == sector])
    if your_choice == "NASDAQ":
        print (NASDAQ[NASDAQ.Sector == sector])
if (option == "4"):
    industry = input ("Please enter the industry: ")
    if your_choice == "AMEX":
        print (AMEX[AMEX.Industry == industry])
    if your_choice == "NYSE":
        print (NYSE[NYSE.Industry == industry])
    if your_choice == "NASDAQ":
        print (NASDAQ[NASDAQ.Industry == industry])
if (option == "5"):
    if your_choice == "AMEX":
        hist = input("Please input the Symbol: ")
        url = "https://www.quandl.com/api/v3/datasets/WIKI/"+hist+".csv?start_date=2018-02-01"
        print(url)
        try:
            hist_df = pd.read_csv(urlopen(url))
            print ("\n------------- Historical value for " + hist+ " -------------------")
            display(hist_df[["Date", "Open", "High", "Low", "Close"]])
        except:
            print ("Error with the symbol: " + hist)
    if your_choice == "NYSE":
        hist = input("Please input the Symbol: ")
        url = "https://www.quandl.com/api/v3/datasets/WIKI/"+hist+".csv?start_date=2018-02-01"
        print(url)
        try:
            hist_df = pd.read_csv(urlopen(url))
            print ("\n------------- Historical value for " + hist+ " -------------------")
            display(hist_df[["Date", "Open", "High", "Low", "Close"]])
        except:
            print ("Error with the symbol: " + hist)
    if your_choice == "NASDAQ":
        hist = input("Please input the Symbol: ")
        url = "https://www.quandl.com/api/v3/datasets/WIKI/"+hist+".csv?start_date=2018-02-01"
        print(url)
        try:
            hist_df = pd.read_csv(urlopen(url))
            print ("\n------------- Historical value for " + hist+ " -------------------")
            display(hist_df[["Date", "Open", "High", "Low", "Close"]])
        except:
            print ("Error with the symbol: " + hist)
# Out:
#  Welcome to our Data Store
# 1) Search for a symbol
# 2) Search for part of the name of a company
# 3) Search for a sector
# 4) Search for an industry
# 5) Historical value
#
# 0) Exit

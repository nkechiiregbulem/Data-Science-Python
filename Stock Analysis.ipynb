# %%
import quandl
import pandas as pd
import csv

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key='7TOTGF7E6UZ6ESJD')
data, meta_data = ts.get_intraday('CME')

# %%
ts = TimeSeries(key='7TOTGF7E6UZ6ESJD',retries='5')

# %%
ts = TimeSeries(key='7TOTGF7E6UZ6ESJD',output_format='pandas')

# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
ts = TimeSeries(key='7TOTGF7E6UZ6ESJD', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='CME',interval='1min', outputsize='full')
pprint(data.head(2000))
# Out:
#                       1. open   2. high    3. low  4. close  5. volume
# date
# 2019-06-04 09:31:00  194.3900  194.6600  194.0400   194.660        0.0
# 2019-06-04 09:32:00  194.5200  194.5300  194.3300   194.345     1285.0
# 2019-06-04 09:33:00  194.1450  194.1450  193.8500   193.850     4147.0
# 2019-06-04 09:34:00  193.8150  193.8700  193.7541   193.830      702.0
# 2019-06-04 09:35:00  193.8000  193.8617  193.6400   193.815     3732.0
# 2019-06-04 09:36:00  193.8000  193.9400  193.6100   193.770    12952.0
# 2019-06-04 09:37:00  193.7100  193.8050  193.6400   193.805      957.0
# 2019-06-04 09:38:00  193.8000  193.8999  193.3400   193.340     7540.0
# 2019-06-04 09:39:00  193.3900  193.4500  193.3000   193.300     2196.0
# 2019-06-04 09:40:00  193.3100  193.4100  193.2000   193.200     4054.0
# 2019-06-04 09:41:00  193.2350  193.2350  192.9700   192.975     3894.0
# 2019-06-04 09:42:00  192.9000  192.9000  192.7500   192.750     1744.0
# ...

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
# %matplotlib notebook

ts = TimeSeries(key='7TOTGF7E6UZ6ESJD', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='CME',interval='5min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the CME stock (5 min)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Technical Indicators

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ti = TechIndicators(key='7TOTGF7E6UZ6ESJD', output_format='pandas')
data, meta_data = ti.get_rsi(symbol='CME', interval='60min', time_period=60)
data.plot()
plt.title('RSI indicator for CME stock (60 min)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from alpha_vantage.techindicators import TechIndicators
import matplotlib.pyplot as plt

ti = TechIndicators(key='7TOTGF7E6UZ6ESJD', output_format='pandas')
data, meta_data = ti.get_macd(symbol='CME', interval='60min', series_type='high')
data.plot()
plt.title('MACD indicator for CME stock (60 min)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Sector Performance

# %%
from alpha_vantage.sectorperformance import SectorPerformances
import matplotlib.pyplot as plt

sp = SectorPerformances(key='7TOTGF7E6UZ6ESJD', output_format='pandas')
data, meta_data = sp.get_sector()
data['Rank A: Real-Time Performance'].plot(kind='bar')
plt.title('Real Time Performance (%) per Sector')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# # Cryptocurrencies

# %%
from alpha_vantage.foreignexchange import ForeignExchange
from pprint import pprint

fx = ForeignExchange(key='7TOTGF7E6UZ6ESJD')
data, _ = fx.get_currency_exchange_rate(from_currency='XRP',to_currency='USD')
pprint(data)
# Out:
# {'1. From_Currency Code': 'XRP',
#  '2. From_Currency Name': 'Ripple',
#  '3. To_Currency Code': 'USD',
#  '4. To_Currency Name': 'United States Dollar',
#  '5. Exchange Rate': '0.42308781',
#  '6. Last Refreshed': '2019-06-08 00:21:45',
#  '7. Time Zone': 'UTC',
#  '8. Bid Price': '-',
#  '9. Ask Price': '-'}
